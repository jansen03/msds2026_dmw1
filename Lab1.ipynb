# %% [markdown]
# # Lab 1: Fishery

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.neighbors import KNeighborsClassifier
import mglearn #library provided by amueller
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/mnt/data/public/fisheries-catch-data/global-catch-data/csv/rfmo_12.csv')
df
# Out:
#          rfmo_id rfmo_name layer_name  year               scientific_name  \
# 0             12     NEAFC       rfmo  1950  Marine fishes not identified
# 1             12     NEAFC       rfmo  1950  Marine fishes not identified
# 2             12     NEAFC       rfmo  1950  Marine fishes not identified
# 3             12     NEAFC       rfmo  1950  Marine fishes not identified
# 4             12     NEAFC       rfmo  1950  Marine fishes not identified
# ...          ...       ...        ...   ...                           ...
# 1084097       12     NEAFC       rfmo  2018               Donax trunculus
# 1084098       12     NEAFC       rfmo  2018           Nassarius mutabilis
# 1084099       12     NEAFC       rfmo  2018           Nassarius mutabilis
# 1084100       12     NEAFC       rfmo  2018           Nassarius mutabilis
# 1084101       12     NEAFC       rfmo  2018           Nassarius mutabilis
#
#                common_name               functional_group  \
# ...

# %%
print(df.shape)     # number of rows, columns
print(df.info())
# Out:
# (1084102, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084102 entries, 0 to 1084101
# Data columns (total 15 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   rfmo_id           1084102 non-null  int64
#  1   rfmo_name         1084102 non-null  object
#  2   layer_name        1084102 non-null  object
#  3   year              1084102 non-null  int64
#  4   scientific_name   1084102 non-null  object
#  5   common_name       1084102 non-null  object
#  6   functional_group  1084102 non-null  object
#  7   commercial_group  1084102 non-null  object
#  8   fishing_entity    1084102 non-null  object
#  9   sector_type       1084102 non-null  object
#  10  catch_status      1084102 non-null  object
#  11  reporting_status  1084102 non-null  object
#  12  gear_name         1084102 non-null  object
#  13  catch_sum         1084102 non-null  float64
#  14  real_value        1084102 non-null  float64
# ...

# %%
df.duplicated().sum() #checks for duplicate
# Out:
# 262600

# %%
df.describe().T
# Out:
#                 count          mean           std           min          25%  \
# rfmo_id     1084102.0  1.200000e+01  0.000000e+00  1.200000e+01    12.000000
# year        1084102.0  1.989451e+03  1.964010e+01  1.950000e+03  1974.000000
# catch_sum   1084102.0  6.898509e+02  1.109438e+04  0.000000e+00     0.001920
# real_value  1084102.0  1.596197e+08  8.862529e+09  7.838210e-24     0.000741
#
#                     50%          75%           max
# rfmo_id       12.000000    12.000000  1.200000e+01
# year        1992.000000  2007.000000  2.018000e+03
# catch_sum      0.132962     8.334396  1.753297e+06
# real_value     1.784866  4191.744391  3.721474e+12
